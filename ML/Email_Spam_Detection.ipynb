# %%
import pandas as pd

df=pd.read_csv("/home/iplab/Desktop/LP-III/MLLP-III/emails.csv")

# %%
df.shape
# Out:
# (5172, 3002)

# %%
x_scaled = df.drop(['Email No.','Prediction'],axis=1)
y = df['Prediction']

# %%
y.value_counts()
# Out:
# 0    3672
# 1    1500
# Name: Prediction, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,random_state=0,test_size = 0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors =5)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8576952822892498

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       929
#            1       0.72      0.82      0.76       364
#
#     accuracy                           0.86      1293
#    macro avg       0.82      0.85      0.83      1293
# weighted avg       0.87      0.86      0.86      1293

# %%
from sklearn.svm import SVC
model = SVC(kernel = 'linear')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.954369682907966

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Create ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

# Plot confusion matrix
disp.plot(cmap='Blues')

# Add accuracy to the plot title
accuracy = accuracy_score(y_test, y_pred)
plt.title(f'SVM Confusion Matrix\nAccuracy: {accuracy:.4f}')

# Show plot
plt.show()
